# %%
from sportsipy.nfl.teams import Teams

for team in Teams():
    print(team.name)
    print(team.dataframe)
# Out:
# Dallas Cowboys
#     abbreviation  defensive_simple_rating_system  first_downs  \
# DAL          DAL                            -1.9          164
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# DAL                          17        3             6              4       1
#
#      margin_of_victory            name  ...  rush_yards  \
# DAL                9.8  Dallas Cowboys  ...         986
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# DAL                     5.1                   9.1                  -0.7
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# DAL          7           0.833     5   2765                   391
#
#      yards_per_play
# DAL             6.6
#
# [1 rows x 40 columns]
# Buffalo Bills
#     abbreviation  defensive_simple_rating_system  first_downs  \
# BUF          BUF                             6.6          146
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# BUF                          11        2             6              3       2
#
#      margin_of_victory           name  ...  rush_yards  \
# BUF               17.5  Buffalo Bills  ...         784
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# BUF                     4.4                  13.1                  -4.4
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# BUF          5           0.667     4   2469                   357
#
#      yards_per_play
# BUF             5.9
#
# [1 rows x 40 columns]
# Tampa Bay Buccaneers
#     abbreviation  defensive_simple_rating_system  first_downs  \
# TAM          TAM                            -0.4          154
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# TAM                           9        3             6              3       1
#
#      margin_of_victory                  name  ...  rush_yards  \
# TAM                8.5  Tampa Bay Buccaneers  ...         512
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# TAM                     3.8                   6.8                  -1.7
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# TAM          6           0.833     5   2556                   471
#
#      yards_per_play
# TAM             6.2
#
# [1 rows x 40 columns]
# Arizona Cardinals
#     abbreviation  defensive_simple_rating_system  first_downs  \
# CRD          CRD                             8.2          137
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# CRD                          10        1             6              4       0
#
#      margin_of_victory               name  ...  rush_yards  \
# CRD               14.2  Arizona Cardinals  ...         784
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# CRD                     4.2                  16.2                   2.0
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# CRD          5             1.0     6   2418                   327
#
#      yards_per_play
# CRD             6.1
#
# [1 rows x 40 columns]
# Kansas City Chiefs
#     abbreviation  defensive_simple_rating_system  first_downs  \
# KAN          KAN                            -4.3          165
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# KAN                          15        6             6              8       3
#
#      margin_of_victory                name  ...  rush_yards  \
# KAN                1.5  Kansas City Chiefs  ...         750
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# KAN                     4.9                   4.1                   2.6
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# KAN         14             0.5     3   2601                   286
#
#      yards_per_play
# KAN             6.4
#
# [1 rows x 40 columns]
# Los Angeles Rams
#     abbreviation  defensive_simple_rating_system  first_downs  \
# RAM          RAM                             2.7          131
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# RAM                           6        2             6              5       1
#
#      margin_of_victory              name  ...  rush_yards  \
# RAM                8.7  Los Angeles Rams  ...         621
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# RAM                     3.8                  10.8                   2.1
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# RAM          7           0.833     5   2406                   226
#
#      yards_per_play
# RAM             6.5
#
# [1 rows x 40 columns]
# Cleveland Browns
#     abbreviation  defensive_simple_rating_system  first_downs  \
# CLE          CLE                            -0.2          156
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# CLE                           9        4             7              3       3
#
#      margin_of_victory              name  ...  rush_yards  \
# CLE                1.1  Cleveland Browns  ...        1193
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# CLE                     5.3                   2.6                   1.5
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# CLE          7           0.571     4   2754                   488
#
#      yards_per_play
# CLE             6.1
#
# [1 rows x 40 columns]
# Baltimore Ravens
#     abbreviation  defensive_simple_rating_system  first_downs  \
# RAV          RAV                             3.3          143
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# RAV                           5        3             6              5       1
#
#      margin_of_victory              name  ...  rush_yards  \
# RAV                7.8  Baltimore Ravens  ...         931
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# RAV                     4.9                   7.3                  -0.5
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# RAV          8           0.833     5   2530                   339
#
#      yards_per_play
# RAV             6.3
#
# [1 rows x 40 columns]
# Tennessee Titans
#     abbreviation  defensive_simple_rating_system  first_downs  \
# OTI          OTI                            -3.3          143
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# OTI                          14        4             6              4       2
#
#      margin_of_victory              name  ...  rush_yards  \
# OTI                0.8  Tennessee Titans  ...         985
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# OTI                     5.1                   2.3                   1.4
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# OTI          8           0.667     4   2308                   359
#
#      yards_per_play
# OTI             5.5
#
# [1 rows x 40 columns]
# Los Angeles Chargers
#     abbreviation  defensive_simple_rating_system  first_downs  \
# SDG          SDG                             3.4          138
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# SDG                          12        2             6              4       2
#
#      margin_of_victory                  name  ...  rush_yards  \
# SDG               -0.3  Los Angeles Chargers  ...         568
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# SDG                     4.1                   2.0                   2.3
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# SDG          6           0.667     4   2265                   432
#
#      yards_per_play
# SDG             5.7
#
# [1 rows x 40 columns]
# Cincinnati Bengals
#     abbreviation  defensive_simple_rating_system  first_downs  \
# CIN          CIN                             3.0          105
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# CIN                           7        1             6              7       2
#
#      margin_of_victory                name  ...  rush_yards  \
# CIN                6.2  Cincinnati Bengals  ...         637
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# CIN                     3.9                   3.8                  -2.3
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# CIN          8           0.667     4   2067                   251
#
#      yards_per_play
# CIN             5.9
#
# [1 rows x 40 columns]
# Minnesota Vikings
#     abbreviation  defensive_simple_rating_system  first_downs  \
# MIN          MIN                             2.5          134
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# MIN                           8        3             6              2       3
#
#      margin_of_victory               name  ...  rush_yards  \
# MIN                1.7  Minnesota Vikings  ...         767
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# MIN                     4.5                   4.8                   3.1
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# MIN          5             0.5     3   2485                   386
#
#      yards_per_play
# MIN             5.9
#
# [1 rows x 40 columns]
# Las Vegas Raiders
#     abbreviation  defensive_simple_rating_system  first_downs  \
# RAI          RAI                            -3.6          121
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# RAI                          14        0             6              4       2
#
#      margin_of_victory               name  ...  rush_yards  \
# RAI                0.5  Las Vegas Raiders  ...         479
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# RAI                     3.3                  -0.6                  -1.1
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# RAI          4           0.667     4   2311                   400
#
#      yards_per_play
# RAI             5.9
#
# [1 rows x 40 columns]
# Green Bay Packers
#     abbreviation  defensive_simple_rating_system  first_downs  \
# GNB          GNB                            -1.0          126
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# GNB                          14        2             6              3       1
#
#      margin_of_victory               name  ...  rush_yards  \
# GNB                1.3  Green Bay Packers  ...         657
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# GNB                     4.2                   1.1                  -0.2
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# GNB          5           0.833     5   2061                   256
#
#      yards_per_play
# GNB             5.7
#
# [1 rows x 40 columns]
# Carolina Panthers
#     abbreviation  defensive_simple_rating_system  first_downs  \
# CAR          CAR                             2.2          134
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# CAR                          17        3             6              7       3
#
#      margin_of_victory               name  ...  rush_yards  \
# CAR                3.7  Carolina Panthers  ...         657
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# CAR                     3.9                   2.0                  -1.6
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# CAR         10             0.5     3   2123                   280
#
#      yards_per_play
# CAR             5.2
#
# [1 rows x 40 columns]
# Seattle Seahawks
#     abbreviation  defensive_simple_rating_system  first_downs  \
# SEA          SEA                             1.0          110
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# SEA                           9        2             6              2       4
#
#      margin_of_victory              name  ...  rush_yards  \
# SEA               -1.5  Seattle Seahawks  ...         664
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# SEA                     4.6                   2.0                   3.5
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# SEA          4           0.333     2   2064                   280
#
#      yards_per_play
# SEA             6.2
#
# [1 rows x 40 columns]
# Denver Broncos
#     abbreviation  defensive_simple_rating_system  first_downs  \
# DEN          DEN                             3.6          141
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# DEN                          12        3             7              6       4
#
#      margin_of_victory            name  ...  rush_yards  \
# DEN                1.9  Denver Broncos  ...         746
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# DEN                     4.5                  -1.7                  -3.5
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# DEN          9           0.429     3   2433                   362
#
#      yards_per_play
# DEN             5.5
#
# [1 rows x 40 columns]
# Indianapolis Colts
#     abbreviation  defensive_simple_rating_system  first_downs  \
# CLT          CLT                             2.7          128
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# CLT                          11        3             6              2       4
#
#      margin_of_victory                name  ...  rush_yards  \
# CLT                1.3  Indianapolis Colts  ...         745
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# CLT                     4.7                   1.0                  -0.3
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# CLT          5           0.333     2   2205                   248
#
#      yards_per_play
# CLT             5.9
#
# [1 rows x 40 columns]
# Philadelphia Eagles
#     abbreviation  defensive_simple_rating_system  first_downs  \
# PHI          PHI                             2.1          115
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# PHI                          10        1             6              4       4
#
#      margin_of_victory                 name  ...  rush_yards  \
# PHI               -2.5  Philadelphia Eagles  ...         682
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# PHI                     5.2                  -0.9                   1.6
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# PHI          5           0.333     2   2076                   382
#
#      yards_per_play
# PHI             5.9
#
# [1 rows x 40 columns]
# Washington Football Team
#     abbreviation  defensive_simple_rating_system  first_downs  \
# WAS          WAS                            -6.8          120
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# WAS                          16        3             6              6       4
#
#      margin_of_victory                      name  ...  rush_yards  \
# WAS               -8.3  Washington Football Team  ...         638
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# WAS                     4.1                  -8.7                  -0.4
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# WAS          9           0.333     2   2017                   341
#
#      yards_per_play
# WAS             5.5
#
# [1 rows x 40 columns]
# New Orleans Saints
#     abbreviation  defensive_simple_rating_system  first_downs  \
# NOR          NOR                             3.4           86
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# NOR                           3        1             5              4       2
#
#      margin_of_victory                name  ...  rush_yards  \
# NOR                7.2  New Orleans Saints  ...         629
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# NOR                     4.0                   3.2                  -4.0
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# NOR          5             0.6     3   1476                   246
#
#      yards_per_play
# NOR             5.2
#
# [1 rows x 40 columns]
# New England Patriots
#     abbreviation  defensive_simple_rating_system  first_downs  \
# NWE          NWE                             1.3          115
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# NWE                          13        5             6              6       4
#
#      margin_of_victory                  name  ...  rush_yards  \
# NWE               -0.3  New England Patriots  ...         520
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# NWE                     3.8                  -3.5                  -3.1
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# NWE         11           0.333     2   1934                   319
#
#      yards_per_play
# NWE             5.3
#
# [1 rows x 40 columns]
# Pittsburgh Steelers
#     abbreviation  defensive_simple_rating_system  first_downs  \
# PIT          PIT                             3.2          112
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# PIT                          12        3             6              4       3
#
#      margin_of_victory                 name  ...  rush_yards  \
# PIT               -2.5  Pittsburgh Steelers  ...         487
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# PIT                     3.7                   0.5                   3.0
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# PIT          7             0.5     3   1943                   279
#
#      yards_per_play
# PIT             5.1
#
# [1 rows x 40 columns]
# San Francisco 49ers
#     abbreviation  defensive_simple_rating_system  first_downs  \
# SFO          SFO                             0.9          111
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# SFO                          15        4             5              3       3
#
#      margin_of_victory                 name  ...  rush_yards  \
# SFO               -0.4  San Francisco 49ers  ...         610
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# SFO                     4.2                   1.7                   2.1
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# SFO          7             0.4     2   1841                   363
#
#      yards_per_play
# SFO             5.8
#
# [1 rows x 40 columns]
# Jacksonville Jaguars
#     abbreviation  defensive_simple_rating_system  first_downs  \
# JAX          JAX                            -5.7          118
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# JAX                          11        4             6              8       5
#
#      margin_of_victory                  name  ...  rush_yards  \
# JAX               -9.3  Jacksonville Jaguars  ...         731
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# JAX                     5.2                  -9.9                  -0.6
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# JAX         12           0.167     1   2136                   289
#
#      yards_per_play
# JAX             5.8
#
# [1 rows x 40 columns]
# New York Giants
#     abbreviation  defensive_simple_rating_system  first_downs  \
# NYG          NYG                            -4.6          123
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# NYG                          13        3             6              6       5
#
#      margin_of_victory             name  ...  rush_yards  \
# NYG              -10.5  New York Giants  ...         539
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# NYG                     3.9                 -10.7                  -0.2
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# NYG          9           0.167     1   2164                   282
#
#      yards_per_play
# NYG             5.6
#
# [1 rows x 40 columns]
# Detroit Lions
#     abbreviation  defensive_simple_rating_system  first_downs  \
# DET          DET                            -4.5          132
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# DET                          15        4             6              4       6
#
#      margin_of_victory           name  ...  rush_yards  \
# DET              -10.5  Detroit Lions  ...         551
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# DET                     4.0                  -7.8                   2.7
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# DET          8             0.0     0   1926                   291
#
#      yards_per_play
# DET             4.9
#
# [1 rows x 40 columns]
# Atlanta Falcons
#     abbreviation  defensive_simple_rating_system  first_downs  \
# ATL          ATL                            -8.8          108
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# ATL                          16        3             5              3       3
#
#      margin_of_victory             name  ...  rush_yards  \
# ATL               -8.6  Atlanta Falcons  ...         455
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# ATL                     3.7                 -14.0                  -5.4
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# ATL          6             0.4     2   1728                   278
#
#      yards_per_play
# ATL             5.1
#
# [1 rows x 40 columns]
# Miami Dolphins
#     abbreviation  defensive_simple_rating_system  first_downs  \
# MIA          MIA                            -4.7          104
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# MIA                          10        5             6              4       5
#
#      margin_of_victory            name  ...  rush_yards  \
# MIA              -13.0  Miami Dolphins  ...         429
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# MIA                     3.7                 -11.9                   1.1
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# MIA          9           0.167     1   1740                   303
#
#      yards_per_play
# MIA             4.7
#
# [1 rows x 40 columns]
# Chicago Bears
#     abbreviation  defensive_simple_rating_system  first_downs  \
# CHI          CHI                             5.4          106
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# CHI                          13        1             6              4       3
#
#      margin_of_victory           name  ...  rush_yards  \
# CHI               -4.3  Chicago Bears  ...         774
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# CHI                     4.4                  -2.7                   1.7
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# CHI          5             0.5     3   1477                   334
#
#      yards_per_play
# CHI             4.3
#
# [1 rows x 40 columns]
# Houston Texans
#     abbreviation  defensive_simple_rating_system  first_downs  \
# HTX          HTX                            -5.1           92
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# HTX                           9        4             6              7       5
#
#      margin_of_victory            name  ...  rush_yards  \
# HTX              -13.3  Houston Texans  ...         523
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# HTX                     3.3                 -12.4                   0.9
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# HTX         11           0.167     1   1766                   374
#
#      yards_per_play
# HTX             5.0
#
# [1 rows x 40 columns]
# New York Jets
#     abbreviation  defensive_simple_rating_system  first_downs  \
# NYJ          NYJ                            -2.4           78
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# NYJ                           8        0             5              9       4
#
#      margin_of_victory           name  ...  rush_yards  \
# NYJ              -10.8  New York Jets  ...         370
#
#      rush_yards_per_attempt  simple_rating_system  strength_of_schedule  \
# NYJ                     3.6                 -13.8                  -3.0
#
#      turnovers  win_percentage  wins  yards  yards_from_penalties  \
# NYJ          9             0.2     1   1335                   320
#
#      yards_per_play
# NYJ             4.6
#
# [1 rows x 40 columns]

# %%
from sportsipy.nfl.teams import Teams

for team in Teams():
    roster = team.roster  # Gets each team's roster
    for player in roster.players:
            print(player.name)  # Prints each players name on the roster

# %%
from sportsipy.nba.schedule import Schedule

# MIL removed from league list as it is used to initiate league_schedule
league = ['CHO','LAL','LAC','SAC','ATL','MIA','DAL','POR',
              'HOU','NOP','PHO','WAS','MEM','BOS','DEN','TOR','SAS',
              'PHI','BRK','UTA','IND','OKC','ORL','MIN','DET',
              'NYK','CLE','CHI','GSW']

league_schedule = Schedule('MIL', year="2020").dataframe
for team in league:
    league_schedule = league_schedule.append(Schedule(team , year="2020").dataframe)

# %%
league_schedule.shape
# Out:
# (2286, 15)

# %%
teams = []
for team in Teams().dataframes.index:
    teams.append(team)

# %%
from sportsipy.nfl.roster import Roster

saints = Roster('NOR')
for player in saints.players:
    # Prints the name of all players who played for the New Orleans Saints
    # in the most recent season.
    print(player.name)

# %%
from sportsipy.nba.schedule import Schedule

por2021 = Schedule('POR', year = '2021').dataframe
por2021.head()
# Out:
#              boxscore_index               date   datetime  game location  \
# 202012230POR   202012230POR  Wed, Dec 23, 2020 2020-12-23     1     Home
# 202012260POR   202012260POR  Sat, Dec 26, 2020 2020-12-26     2     Home
# 202012280LAL   202012280LAL  Mon, Dec 28, 2020 2020-12-28     3     Away
# 202012300LAC   202012300LAC  Wed, Dec 30, 2020 2020-12-30     4     Away
# 202101010GSW   202101010GSW   Fri, Jan 1, 2021 2021-01-01     5     Away
#
#               losses opponent_abbr          opponent_name  playoffs  \
# 202012230POR       1           UTA              Utah Jazz     False
# 202012260POR       1           HOU        Houston Rockets     False
# 202012280LAL       1           LAL     Los Angeles Lakers     False
# 202012300LAC       2           LAC   Los Angeles Clippers     False
# 202101010GSW       2           GSW  Golden State Warriors     False
#
#               points_allowed  points_scored result streak    time  wins
# 202012230POR             120            100   Loss    L 1  10:00p     0
# 202012260POR             126            128    Win    W 1  10:00p     1
# 202012280LAL             107            115    Win    W 2  10:00p     2
# 202012300LAC             128            105   Loss    L 1  10:00p     2
# 202101010GSW              98            123    Win    W 1  10:30p     3

# %%
from sportsipy.nba.boxscore import Boxscore

for boxscore in por2021['boxscore_index']:
    try:
        pd.concat(boxscores_df, Boxscore(boxscore).dataframe)
    except:
        boxscores_df = Boxscore(boxscore).dataframe
    

boxscores_df
# Out:
#               away_assist_percentage  away_assists  away_block_percentage  \
# 202106030POR                    63.6            28                    7.0
#
#               away_blocks  away_defensive_rating  \
# 202106030POR            3                  119.8
#
#               away_defensive_rebound_percentage  away_defensive_rebounds  \
# 202106030POR                               78.4                       29
#
#               away_effective_field_goal_percentage  away_field_goal_attempts  \
# 202106030POR                                 0.599                        86
#
#               away_field_goal_percentage  ...  \
# 202106030POR                       0.512  ...
#
#               home_two_point_field_goal_percentage  \
# 202106030POR                                 0.581
#
#               home_two_point_field_goals  home_wins  \
# 202106030POR                          25          2
#
#                                    location  losing_abbr  \
# 202106030POR  Moda Center, Portland, Oregon          POR
#
#                          losing_name  pace  winner  winning_abbr  \
# 202106030POR  Portland Trail Blazers  96.0    Away           DEN
#
#                 winning_name
# 202106030POR  Denver Nuggets
#
# [1 rows x 82 columns]

# %%
from sportsipy.nfl.teams import Teams
from sportsipy.nfl.roster import Player
from sportsipy.nfl.roster import Roster

player_count = 0

for team in Teams(2020):
    print(team)
#     roster = trosteream.roster
#     for player in roster.players:
#         player_count += 1
#     print(player_count)
# Out:
# Green Bay Packers (GNB) - 2020
# Buffalo Bills (BUF) - 2020
# Tampa Bay Buccaneers (TAM) - 2020
# Tennessee Titans (OTI) - 2020
# New Orleans Saints (NOR) - 2020
# Kansas City Chiefs (KAN) - 2020
# Baltimore Ravens (RAV) - 2020
# Seattle Seahawks (SEA) - 2020
# Indianapolis Colts (CLT) - 2020
# Las Vegas Raiders (RAI) - 2020
# Minnesota Vikings (MIN) - 2020
# Pittsburgh Steelers (PIT) - 2020
# Arizona Cardinals (CRD) - 2020
# Cleveland Browns (CLE) - 2020
# Miami Dolphins (MIA) - 2020
# Atlanta Falcons (ATL) - 2020
# Dallas Cowboys (DAL) - 2020
# Houston Texans (HTX) - 2020
# Los Angeles Chargers (SDG) - 2020
# Detroit Lions (DET) - 2020
# San Francisco 49ers (SFO) - 2020
# Los Angeles Rams (RAM) - 2020
# Chicago Bears (CHI) - 2020
# Carolina Panthers (CAR) - 2020
# Washington Football Team (WAS) - 2020
# Philadelphia Eagles (PHI) - 2020
# New England Patriots (NWE) - 2020
# Denver Broncos (DEN) - 2020
# Cincinnati Bengals (CIN) - 2020
# Jacksonville Jaguars (JAX) - 2020
# New York Giants (NYG) - 2020
# New York Jets (NYJ) - 2020

# %%
Roster
# Out:
# sportsipy.nfl.roster.Roster

# %%
team_abv = []
for team in Teams(year = 2020).dataframes.index:
#      print('\n' + team + '\n')
      team_abv.append(team)

# %%
team_abv
# Out:
# ['GNB',
#  'BUF',
#  'TAM',
#  'OTI',
#  'NOR',
#  'KAN',
#  'RAV',
#  'SEA',
#  'CLT',
#  'RAI',
#  'MIN',
#  'PIT',
#  'CRD',
#  'CLE',
#  'MIA',
#  'ATL',
#  'DAL',
#  'HTX',
#  'SDG',
#  'DET',
#  'SFO',
#  'RAM',
#  'CHI',
#  'CAR',
#  'WAS',
#  'PHI',
#  'NWE',
#  'DEN',
#  'CIN',
#  'JAX',
#  'NYG',
#  'NYJ']

# %%
from sportsipy.nfl.roster import Roster

saints = Roster('NOR')
for player in saints.players:
    # Prints the name of all players who played for the New Orleans Saints
    # in the most recent season.
    print(player.name)

# %%
player_count = 0

for team in Teams(2020):
    schedule = Schedule(team)
    for game in schedule:
        print(game.boxscore_index)
    
    
#         player_count += 1
#     print(player_count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-69f845944c0d> in <module>
#       2
#       3 for team in Teams(2020):
# ----> 4     schedule = Schedule(team)
#       5 schedule.head()
#       6 #     for game in schedule:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sportsipy\nba\schedule.py in __init__(self, abbreviation, year)
#     313     def __init__(self, abbreviation, year=None):
#     314         self._games = []
# --> 315         self._pull_schedule(abbreviation, year)
#     316
#     317     def __getitem__(self, index):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sportsipy\nba\schedule.py in _pull_schedule(self, abbreviation, year)
#     443             # previous year's stats. If it exists, use the previous year
#     444             # instead.
# --> 445             if not utils._url_exists(SCHEDULE_URL % (abbreviation.lower(),
#     446                                                      year)) and \
#     447                utils._url_exists(SCHEDULE_URL % (abbreviation.lower(),
#
# AttributeError: 'Team' object has no attribute 'lower'

# %%
from sportsipy.nfl.schedule import Schedule
team_schedule = []

for i in range(len(team_abv)):
    
    schedule = list(Schedule(team_abv[i], year = '2020'))
    team_schedule.append(schedule)

# %%
#team_schedule is a list of list for each teams schedule in 2020
regular_season = []
for s in team_schedule:
    regular_season.append(s[0:16])

# %%
boxscore_index_list = []
for team_sch in regular_season:
    #print(team_sch)
    for game in team_sch:
        #print(game.boxscore_index)  # Prints the boxscore URI for each game
        boxscore = game.boxscore_index  # Returns an instance of the Boxscore class for this specific game
        boxscore_index_list.append(boxscore)

# %%
from sportsipy.nfl.boxscore import Boxscore
boxscore_index_list[1]
# Out:
# '202009200gnb'

# %%
Boxscore('202109120nwe')
# Out:
# Boxscore for Miami Dolphins at New England Patriots (Sunday Sep 12, 2021)

# %%
game_data_list=[]

for i in range(len(boxscore_index_list)):#boxscore_index_list:
    game_data = Boxscore(boxscore_index_list[i])
    #print(game_data)
    game_data_list.append(game_data)

# %%
len(game_data_list)
# Out:
# 227

# %%
import pandas as pd
def home_away_split(game_data):
    #Home
    home_df = game_data.home_players[0].dataframe
    for player in game_data.home_players[1:]:
        home_df = pd.concat([home_df, player.dataframe], axis = 0)
    home_df['name'] = [x.name for x in game_data.home_players]
    home_df.set_index('name', inplace = True)
    away_df = game_data.away_players[0].dataframe
    
    #Away
    for player in game_data.away_players[1:]:
        away_df = pd.concat([away_df, player.dataframe], axis = 0)
    away_df['name'] = [x.name for x in game_data.away_players]
    away_df.set_index('name', inplace = True)

    return home_df, away_df

# %%
full_df_home = []
x = 0
for i in range(1): # len(game_data_list)
    x = x+1
    
    if x <= 16:
        x = x
    else:
        x = 1
    #data for home game x
    first_df, second_df = home_away_split(game_data_list[i])
    first_df['Week'] = x
    full_df_home.append(first_df)
    #print(x)

# %%
test = pd.concat(full_df_home)
test.head(10)
# Out:
#                    completed_passes attempted_passes passing_yards  \
# name
# Kirk Cousins                     19               25           259
# Alexander Mattison                0                0             0
# Dalvin Cook                       0                0             0
# Adam Thielen                      0                0             0
# Olabisi Johnson                   0                0             0
# Kyle Rudolph                      0                0             0
# Justin Jefferson                  0                0             0
# Irv Smith Jr.                     0                0             0
# Tajae Sharpe                      0                0             0
# Eric Kendricks                 None             None          None
#
#                    passing_touchdowns interceptions_thrown times_sacked  \
# name
# Kirk Cousins                        2                    1            2
# Alexander Mattison                  0                    0            0
# Dalvin Cook                         0                    0            0
# Adam Thielen                        0                    0            0
# Olabisi Johnson                     0                    0            0
# Kyle Rudolph                        0                    0            0
# Justin Jefferson                    0                    0            0
# Irv Smith Jr.                       0                    0            0
# Tajae Sharpe                        0                    0            0
# Eric Kendricks                   None                 None         None
#
#                    yards_lost_from_sacks longest_pass  quarterback_rating  \
# name
# Kirk Cousins                          11           37               118.6
# Alexander Mattison                     0            0                 NaN
# Dalvin Cook                            0            0                 NaN
# Adam Thielen                           0            0                 NaN
# Olabisi Johnson                        0            0                 NaN
# Kyle Rudolph                           0            0                 NaN
# Justin Jefferson                       0            0                 NaN
# Irv Smith Jr.                          0            0                 NaN
# Tajae Sharpe                           0            0                 NaN
# Eric Kendricks                      None         None                 NaN
#
#                    rush_attempts  ... longest_punt_return extra_points_made  \
# name                              ...
# Kirk Cousins                   4  ...                None              None
# Alexander Mattison             6  ...                None              None
# Dalvin Cook                   12  ...                None              None
# Adam Thielen                   0  ...                None              None
# Olabisi Johnson                0  ...                None              None
# Kyle Rudolph                   0  ...                None              None
# Justin Jefferson               0  ...                None              None
# Irv Smith Jr.                  0  ...                None              None
# Tajae Sharpe                   0  ...                None              None
# Eric Kendricks              None  ...                None              None
#
#                    extra_points_attempted field_goals_made  \
# name
# Kirk Cousins                         None             None
# Alexander Mattison                   None             None
# Dalvin Cook                          None             None
# Adam Thielen                         None             None
# Olabisi Johnson                      None             None
# Kyle Rudolph                         None             None
# Justin Jefferson                     None             None
# Irv Smith Jr.                        None             None
# Tajae Sharpe                         None             None
# Eric Kendricks                       None             None
#
#                    field_goals_attempted punts total_punt_yards  \
# name
# Kirk Cousins                        None  None             None
# Alexander Mattison                  None  None             None
# Dalvin Cook                         None  None             None
# Adam Thielen                        None  None             None
# Olabisi Johnson                     None  None             None
# Kyle Rudolph                        None  None             None
# Justin Jefferson                    None  None             None
# Irv Smith Jr.                       None  None             None
# Tajae Sharpe                        None  None             None
# Eric Kendricks                      None  None             None
#
#                    yards_per_punt longest_punt Week
# name
# Kirk Cousins                 None         None    1
# Alexander Mattison           None         None    1
# Dalvin Cook                  None         None    1
# Adam Thielen                 None         None    1
# Olabisi Johnson              None         None    1
# Kyle Rudolph                 None         None    1
# Justin Jefferson             None         None    1
# Irv Smith Jr.                None         None    1
# Tajae Sharpe                 None         None    1
# Eric Kendricks               None         None    1
#
# [10 rows x 54 columns]

# %%
full_df_home.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
schedule = Schedule(team_abv[0], year = '2020')
schedule
# Out:
# September 13 - MIN
# September 20 - DET
# September 27 - NOR
# October 5 - ATL
# October 18 - TAM
# October 25 - HTX
# November 1 - MIN
# November 5 - SFO
# November 15 - JAX
# November 22 - CLT
# November 29 - CHI
# December 6 - PHI
# December 13 - DET
# December 19 - CAR
# December 27 - OTI
# January 3 - CHI
# January 16 - RAM
# January 24 - TAM

# %%
team_schedules
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-4d3d473ec105> in <module>
# ----> 1 team_schedules
#
# NameError: name 'team_schedules' is not defined

# %%
for game in newengland_schedule:
    print(game.boxscore_index)  # Prints the boxscore URI for each game
    boxscore = game.boxscore  # Returns an instance of the Boxscore class for this specific game
