# %%
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine
from config import db_password

# %%
# Create the connection to the PostgreSQL database
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/DFS"
engine = create_engine(db_string)
# movies_df.to_sql(name='movies', con=engine, if_exists='replace')
playerdata2020_df = pd.read_sql_table('nfl2020final', con=engine, index_col='name')

# %%
playerdata2020_df
# Out:
#                     completed_passes  attempted_passes  passing_yards  \
# name
# Kirk Cousins                      19                25            259
# Alexander Mattison                 0                 0              0
# Dalvin Cook                        0                 0              0
# Adam Thielen                       0                 0              0
# Olabisi Johnson                    0                 0              0
# ...                              ...               ...            ...
# Wayne Gallman                      0                 0              0
# Dion Lewis                         0                 0              0
# Alfred Morris                      0                 0              0
# Sterling Shepard                   0                 0              0
# Evan Engram                        0                 0              0
#
#                     passing_touchdowns  interceptions_thrown  times_sacked  \
# name
# Kirk Cousins                         2                     1             2
# Alexander Mattison                   0                     0             0
# Dalvin Cook                          0                     0             0
# Adam Thielen                         0                     0             0
# Olabisi Johnson                      0                     0             0
# ...                                ...                   ...           ...
# Wayne Gallman                        0                     0             0
# Dion Lewis                           0                     0             0
# Alfred Morris                        0                     0             0
# Sterling Shepard                     0                     0             0
# Evan Engram                          0                     0             0
#
#                     yards_lost_from_sacks  longest_pass  quarterback_rating  \
# name
# Kirk Cousins                           11            37               118.6
# Alexander Mattison                      0             0                 0.0
# Dalvin Cook                             0             0                 0.0
# Adam Thielen                            0             0                 0.0
# Olabisi Johnson                         0             0                 0.0
# ...                                   ...           ...                 ...
# Wayne Gallman                           0             0                 0.0
# Dion Lewis                              0             0                 0.0
# Alfred Morris                           0             0                 0.0
# Sterling Shepard                        0             0                 0.0
# Evan Engram                             0             0                 0.0
#
#                     rush_attempts  ...  receiving_touchdowns  \
# name                               ...
# Kirk Cousins                    4  ...                     0
# Alexander Mattison              6  ...                     0
# Dalvin Cook                    12  ...                     0
# Adam Thielen                    0  ...                     2
# Olabisi Johnson                 0  ...                     0
# ...                           ...  ...                   ...
# Wayne Gallman                  24  ...                     0
# Dion Lewis                      2  ...                     0
# Alfred Morris                   4  ...                     0
# Sterling Shepard                1  ...                     0
# Evan Engram                     0  ...                     0
#
#                     longest_reception  fumbles  fumbles_lost  \
# name
# Kirk Cousins                        0        0             0
# Alexander Mattison                  9        0             0
# Dalvin Cook                        -2        0             0
# Adam Thielen                       37        0             0
# Olabisi Johnson                    29        0             0
# ...                               ...      ...           ...
# Wayne Gallman                       4        0             0
# Dion Lewis                          7        0             0
# Alfred Morris                       0        0             0
# Sterling Shepard                   16        0             0
# Evan Engram                        53        1             1
#
#                     fumbles_recovered_for_touchdown  kickoff_return_touchdown  \
# name
# Kirk Cousins                                      0                         0
# Alexander Mattison                                0                         0
# Dalvin Cook                                       0                         0
# Adam Thielen                                      0                         0
# Olabisi Johnson                                   0                         0
# ...                                             ...                       ...
# Wayne Gallman                                     0                         0
# Dion Lewis                                        0                         0
# Alfred Morris                                     0                         0
# Sterling Shepard                                  0                         0
# Evan Engram                                       0                         0
#
#                     punt_return_touchdown  position  fantasy_points  team
# name
# Kirk Cousins                            0        QB           20.76   MIN
# Alexander Mattison                      0        RB           12.00   MIN
# Dalvin Cook                             0        RB           17.80   MIN
# Adam Thielen                            0        WR           32.00   MIN
# Olabisi Johnson                         0        WR            8.60   MIN
# ...                                   ...       ...             ...   ...
# Wayne Gallman                           0        RB           18.10   NYG
# Dion Lewis                              0        RB            2.70   NYG
# Alfred Morris                           0        RB            0.80   NYG
# Sterling Shepard                        0        WR           13.80   NYG
# Evan Engram                             0        TE           20.90   NYG
#
# [4286 rows x 26 columns]
